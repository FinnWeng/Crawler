# %%
import re
import pandas as pd
import requests
from bs4 import BeautifulSoup
from nltk.tokenize import RegexpTokenizer
import json
from datetime import datetime, timedelta 
import time

# %%
def article_crawler(url):
    resp = requests.get(url)
    soup = BeautifulSoup(resp.text, 'html5lib')
    desc = soup.select("div.text > p")
    b = "".join([p.text for p in desc])
    return b

# %%
def list_crawler(startdate):
    url = "http://news.ltn.com.tw/list/newspaper/politics/%s"
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36"}
    domainname = "http://news.ltn.com.tw/" 
    
    date = datetime.strptime(startdate, "%Y-%m-%d") 
    delta = timedelta(days = 1) 
    dates = [] 

    while date <= datetime.now(): 
        dates.append(date.strftime("%Y-%m-%d")) 
        date += delta
    
    article_data = []


    for p in dates:
        resp = requests.get(url%p,headers=headers)
        soup = BeautifulSoup(resp.text, 'html5lib')
        urls = [domainname + x.get('href') for x in soup.select('div.whitecon > ul > li')[0].select("a")]
        for article_url in urls:
            article_data.append(article_crawler(article_url))
                  
    return article_data

# %%
url = "http://www.chinatimes.com/history-by-date/2014-01-01-2601"
headers = {"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36"}
domainname = "http://"

# %%
date = datetime.strptime("2017-01-01", "%Y-%m-%d") 
delta = timedelta(days = 1) 
dates = [] 

while date <= datetime.now(): 
    dates.append(date.strftime("%Y-%m-%d")) 
    date += delta
# search by date

# %%
url2 = "http://www.chinatimes.com/history-by-date/2017-11-02-260118#"
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36"}
resp = requests.get(url2,headers=headers)
soup = BeautifulSoup(resp.text, 'html5lib')

pages = []
pages = [x.get('href') for x in soup.select('div.pagination > ul > li > a')]
pages[:-2]
# Out:
# []

# %%
url = "http://www.chinatimes.com/history-by-date/%s" 
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36"}

domainname = "http://www.chinatimes.com/" 
           
date = datetime.strptime("2016-12-20", "%Y-%m-%d") 
delta = timedelta(days = 1) 
dates = []
splitpoint = datetime.strptime("2016-12-31", "%Y-%m-%d") 

while date <= splitpoint: 
    dates.append(date.strftime("%Y-%m-%d")) 
    date += delta

dates

urls =[]

for p in dates:
    resp = requests.get(url%p+"-260102",headers=headers)
    soup = BeautifulSoup(resp.text, 'html5lib')
    
    a = [domainname + x.get('href') for x in soup.select('div.listRight > ul > li > h2 > a')]
    urls.extend(a)
    
    pages = []
    pages = [x.get('href') for x in soup.select('div.pagination > ul > li > a')]
    pages = pages[:-2]
    
    if len(pages) > 0 :
        for pages in pages:
            resp = requests.get(domainname+pages,headers=headers)
            soup = BeautifulSoup(resp.text, 'html5lib')
            a = [domainname + x.get('href') for x in soup.select('div.listRight > ul > li > h2 > a')]
            urls.extend(a)

# %%
# Out:
# ['http://www.chinatimes.com//newspapers/20161220000347-260118',
#  'http://www.chinatimes.com//newspapers/20161220000351-260110',
#  'http://www.chinatimes.com//newspapers/20161220000357-260118',
#  'http://www.chinatimes.com//newspapers/20161220000360-260118',
#  'http://www.chinatimes.com//newspapers/20161220000361-260118',
#  'http://www.chinatimes.com//newspapers/20161220000362-260118',
#  'http://www.chinatimes.com//newspapers/20161220000364-260118',
#  'http://www.chinatimes.com//newspapers/20161220000366-260118',
#  'http://www.chinatimes.com//newspapers/20161220000368-260118',
#  'http://www.chinatimes.com//newspapers/20161220000369-260118',
#  'http://www.chinatimes.com//newspapers/20161220000371-260118',
#  'http://www.chinatimes.com//newspapers/20161220000372-260118',
#  'http://www.chinatimes.com//newspapers/20161220000374-260118',
#  'http://www.chinatimes.com//newspapers/20161220000376-260118',
#  'http://www.chinatimes.com//newspapers/20161220000379-260108',
# ...

# %%
hash("mothor")
# Out:
# 4520143948093938599
